# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 3.

# %% [markdown]
# # Importing Data

# %%
path = r'C:\Users\drbar\Documents\Career Foundry\Projects\04 - 25 Instacart Basket Analysis'

# %%
df_prods_ords = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'))

# %%
df_prods_ords.shape
# Out:
# (32640698, 10)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %% [markdown]
# ## 4.

# %%
# Checking the shape of each dataframe
df_prods_ords.shape
# Out:
# (32640698, 10)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %% [markdown]
# ## 5.

# %%
# Checking the head of each dataframe before deciding how to merge
df_prods_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         1   112108             4                   4                 10
# 1         2   202279             3                   5                  9
# 2         2   202279             3                   5                  9
# 3         2   202279             3                   5                  9
# 4         2   202279             3                   5                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered     _merge
# 0                     9.0         NaN                NaN        NaN  left_only
# 1                     8.0     33120.0                1.0        1.0       both
# 2                     8.0     28985.0                2.0        1.0       both
# 3                     8.0      9327.0                3.0        0.0       both
# 4                     8.0     45918.0                4.0        1.0       both

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Removing the Unnamed: 0 column from df_prods
df_prods_2 = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods_2
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Testing merge of dataframes on the common column of product_id
pd.merge(df_prods_2,df_prods_ords, on = ['product_id'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
# Merging the dataframes
df_merged = pd.merge(df_prods_2, df_prods_ords, on = ['product_id'])

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %% [markdown]
# ## 6.

# %%
# Checking merge flag
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# ## 7.

# %%
# Exporting merged dataframe
df_merged.to_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))
